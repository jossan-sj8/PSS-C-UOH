# %% [markdown]
# <a href="https://colab.research.google.com/github/jossan-sj8/PSS-C-UOH/blob/main/Arreglos_en_memoria.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Arreglos en memoria

# %% [markdown]
# Variables Globales

# %% [markdown]
# 1. No se pueden asignar un espacio de memoria en una variable global que ya fue creada y asignada.

# %%
# %%writefile arreglo.c
#
# #include <stdio.h>
#
# int a[4]={2,4,6,8};
#
# int main(){
#   a[0]= 2;
#   a = malloc(10*sizeof(int));
# }
# Out:
# Overwriting arreglo.c

# %%
# !gcc arreglo.c -o arreglo &&./arreglo
# Out:
# arreglo.c: In function ‘main’:
# arreglo.c:8:5: error: assignment to expression with array type
#     8 |   a = malloc(10*sizeof(int));
#       |     ^

# %% [markdown]
# Arreglos de char

# %%
# %%writefile char.c
#
# #include <stdio.h>
#
#
# char a[5]="hola";
#
# int main(){
#     char b[]="hola";
#     char c[]={'h','o','l','a',0};
#
#     a[0]='H';
#     b[3]='A';
#
#     printf("String a: %s\n", a);
#     printf("String b: %s\n", b);
#     printf("String c: %s\n", c);
# }
# Out:
# Writing char.c

# %%
# !gcc char.c -o char && ./char
# Out:
# String a: Hola
# String b: holA
# String c: hola

# %% [markdown]
# Strings -> punteros a char

# %%
# %%writefile string.c
#
# #include <stdio.h>
#
# char *a= "hola";
#
# void f(){
#   char *q="hola";
#   printf("Dirección almacenada en puntero q: %p\n", (void *)q);
# }
#
# int main(){
#   printf("Dirección almacenada en puntero a: %p\n", (void *)a);
#   char *s="chao";
#   char *p="carol";
#
#   printf("Dirección almacenada en puntero s: %p\n", (void *)s);
#   printf("Dirección almacenada en puntero p: %p\n", (void *)p);
#   f();
#
#   return 0;
# }
# Out:
# Writing string.c

# %%
# !gcc string.c -o string && ./string
# Out:
# Dirección almacenada en puntero a: 0x5b0d7e7f2008
# Dirección almacenada en puntero s: 0x5b0d7e7f2060
# Dirección almacenada en puntero p: 0x5b0d7e7f2065
# Dirección almacenada en puntero q: 0x5b0d7e7f2008
