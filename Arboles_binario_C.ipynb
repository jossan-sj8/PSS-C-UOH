# %% [markdown]
# <a href="https://colab.research.google.com/github/jossan-sj8/PSS-C-UOH/blob/main/Arboles_binario_C.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Implementación arbol binario en C

# %%
# %%writefile arbol.c
#
# #include <stdio.h>
# #include <stdlib.h>
#
# struct node {
# 	int data;
# 	struct node* left;
# 	struct node* right;
# };
#
#
# // nuevonodo crea un nodo dado un valor y deja sus punteros a NULL
# struct node* nuevonodo(int data)
# {
# 	struct node* node	= (struct node*)malloc(sizeof(struct node));
# 	node->data = data;
# 	node->left = NULL;
# 	node->right = NULL;
# 	return (node);
# }
#
# void imprimir(struct node *nodo) {
#     if (nodo != NULL) {
#         printf("%d,", nodo->data);
#         imprimir(nodo->left);
#         imprimir(nodo->right);
#     }
# }
#
# int main()
# {
# 	//creamos la instancia nodo
# 	struct node* root = nuevonodo(1);
#   //luego agregar los nodos hijos (nodos hojas)
#
# 	root->left = nuevonodo(2);
# 	root->right = nuevonodo(3);
#
#   //agregar la siguiente generación (nivel)
# 	root->left->left = nuevonodo(4);
#
# 	imprimir(root);
# 	return 0;
# }
# Out:
# Writing arbol.c

# %%
# %%script bash
#
# gcc arbol.c -o arbol

# %%
# !./arbol
# Out:
# 1,2,4,3,
