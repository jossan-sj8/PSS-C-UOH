# %% [markdown]
# <a href="https://colab.research.google.com/github/jossan-sj8/PSS-C-UOH/blob/main/HolaMundo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # hola mundo

# %%
# %%writefile hola_mundo.c
# #include <stdio.h>
#
# int main(){
#   printf("Hola mundo\n");
#   return 0;
# }
# Out:
# Overwriting hola_mundo.c

# %%
# !gcc hola_mundo.c -o hola && ./hola
# Out:
# Hola mundo
