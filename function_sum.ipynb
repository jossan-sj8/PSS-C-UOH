# %% [markdown]
# <a href="https://colab.research.google.com/github/jossan-sj8/PSS-C-UOH/blob/main/function_sum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# function_suma

# %%
# %%writefile sum.c
# #include <stdio.h>
# int main(){
#   int a = 5;
#   int b = 7;
#
#   int suma = a + b;
#
#   printf("La suma de %d + %d es: %d",a,b,suma);
#   return 0;
# }
# Out:
# Overwriting sum.c

# %%
# !gcc sum.c -o suma && ./suma
# Out:
# La suma de 5 + 7 es: 12
