# %% [markdown]
# <a href="https://colab.research.google.com/github/jossan-sj8/PSS-C-UOH/blob/main/Operaciones%20de%20bits.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Operaciones de bits

# %% [markdown]
# 1-. Ejemplo de desplazamiento a la derecha (Right shift)

# %%
# %%writefile ejemplo1.c
# #include <stdio.h>
#
# int main()
# {
#
#   int a=-10;
#   printf("%d\n",a>>1);
#
# }
# Out:
# Overwriting ejemplo1.c

# %%
# !gcc ejemplo1.c -o ejem1 && ./ejem1
# Out:
# -5

# %% [markdown]
# 2-. Ejemplo de desplazamiento usando una variable unsigned

# %%
# %%writefile ejemplo2.c
# #include <stdio.h>
#
#
# int main()
# {
#
#   unsigned char a=255;
#   printf("%d\n",a<<1);
#
# }
# Out:
# Overwriting ejemplo2.c

# %%
# !gcc ejemplo2.c -o ejem2 && ./ejem2
# Out:
# 510

# %% [markdown]
# ## Operaciones de bits: Máscaras de bits.

# %% [markdown]
# Ejemplo: Implemente la función int int_size() que determine el tamaño en bits de una variable int en esta máquina

# %%
# %%writefile intfunc.c
#
# #include <stdio.h>
#
# int int_size(){
#     unsigned int i=~0;
#     int size=0;
#     while(i){
#        size++;
#        i=i>>1;
#     }
#     return size;
#
# }
#
# int main(){
#     printf("La variable tipo int en esta máquina tiene %d bits.\n", int_size());
#     return 0;
# }
# Out:
# Writing intfunc.c

# %%
# !gcc intfunc.c -o intfunc && ./intfunc
# Out:
# La variable tipo int en esta máquina tiene 32 bits.
